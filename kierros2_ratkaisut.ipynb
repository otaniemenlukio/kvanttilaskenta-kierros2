# %% [markdown]
# # Kierros 2 tehtävien ratkaisut
# -tehtävä 1 X operaattorin matriisiesitys

# %% [markdown]
# ## Tehtävä1
# Kvanttitietokoneen muistissa tieto esitetään kubittien avulla. Kubitin perustilat  $\ket 0$ ja $\ket{1}$ esitetään pystyvektoreina
#
# $$
# \begin{align}
# \ket 0 &= \begin{pmatrix} 1 \\ 0 \end{pmatrix}, \\
# \ket 1 &= \begin{pmatrix} 0 \\ 1 \end{pmatrix}.
# \end{align}
# $$
#
# NOT-portin matriisiesitys on seuraava:
#
# $$
# X=\begin{pmatrix} 0 & 1 \\ 1 & 0 \end{pmatrix}
# $$
#
# a) Osoita laskemalla (ohjelmoimalla) matriisin $X$ ja pystyvektorien tulot, että kun $X$-portti operoi kubittiin, niin kubitin tila muuttuu käänteiseksi (bit-flip gate).
#
# a) Osoita matriisiesityksen avulla, että
# $$
# X\ket 0 = \ket 1 \\
# $$
#
# Eli laske
#
# $$
# \left(\begin{matrix}
# 0&1\\
# 1&0
# \end{matrix}\right)\left(\begin{matrix}
# 1\\
# 0
# \end{matrix}\right)
# $$
#
# b) Osoita matriisiesityksen avulla, että
#
# $$
# X\ket 1 = \ket 0 \\
# $$
#
# Eli laske
#
# $$
# \left(\begin{matrix}
# 0&1\\
# 1&0
# \end{matrix}\right)\left(\begin{matrix}
# 0\\
# 1
# \end{matrix}\right)
# $$
#
# c) X-portilla operoiminen voidaan esittää kubitin tilavektorin kiertona ns. Blochin pallon pinnalla. Tutki X-portin vaikutusta kubitin tilaan <a href = "https://bloch.ollpu.fi/"> simulaation avulla</a>. Kun operoit X-portilla tilassa $\ket 0$ olevaan kubittiin, niin kubitti kiertyy X-akselin ympäri tilaan $\ket 1$. Mitä tapahtuu, jos alkutilassa 0 olevaan kubittiin kohdistetaan kaksi peräkkäistä X operaatiota?
#
# d) Osoita laskemalla matriisien tulo, että $XX=I$, missä $I$ on yksikkömatriisi.
#
# $$
# I=\left(\begin{matrix}
# 1&0\\
# 0&1
# \end{matrix}\right)
# $$
#
# eli laske
#
# $$
# XX=\left(\begin{matrix}
# 0&1\\
# 1&0
# \end{matrix}\right)\left(\begin{matrix}
# 0&1\\
# 1&0
# \end{matrix}\right)
# $$
#
# Pythonissa matriisin ja pystyvektorin tulo-operaattori on `*` (tai @).

# %%
# Laske tehtävä 1a,1b1d tähän 1c voit vastata kommenttina, 
#\n on rivinvaihto tulostuksessa
import numpy as np

X =  np.matrix([[0, 1],[1, 0]])
print("Matriisiesitys X,  eli kierto X-akselin ympäri Blochin pallolla.\n",X)

# määritellään pystyvektorina kubitin kvanttitila 0:
q0 = np.matrix([[1],[0]])
print("Kubitin tila 0 pystyvektorina:\n", q0)

# määritellään pystyvektorina kubitin kvanttitila 1:
q1 = np.matrix([[0],[1]])
print("kubitin tila 1 pystyvektorina:\n", q1)
# käytä print() komentoa vastauksen tulostamiseen, tulo operaattori on pythonissa *

print("X operaatio kubitin tilaan 0\n",X*q0,"\n tuloksena tila 1")
print("X operaatio kubitin tilaan 1\n",X*q1)
print("Lasketaan X*X, tuloksena identiteetti\n",X*X)
# Out:
# Matriisiesitys X,  eli kierto X-akselin ympäri Blochin pallolla.
#  [[0 1]
#  [1 0]]
# Kubitin tila 0 pystyvektorina:
#  [[1]
#  [0]]
# kubitin tila 1 pystyvektorina:
#  [[0]
#  [1]]
# X operaatio kubitin tilaan 0
#  [[0]
#  [1]]
#  tuloksena tila 1
# X operaatio kubitin tilaan 1
#  [[1]
#  [0]]
# Lasketaan X*X, tuloksena identiteetti
#  [[1 0]
#  [0 1]]

# %% [markdown]
# ## Tehtävä 2
#
# Tee seuraavaan koodilohkoon yhden kubitin kvanttipiiri, jossa operoit kubittiin ensiksi $X$-portilla, ja sitten $H$-portilla. Kubitin lopputila pitäisi olla $\ket -$.
#
# Hadamardin operaattorille löytyy qiskitistä portti koodilla `h`.

# %%
import numpy as np
from qiskit import *
from qiskit.quantum_info import *
from qiskit.visualization import plot_bloch_multivector

# Luo yhden kubitin kvanttipiiri
circuit = QuantumCircuit(1)


# Lisää portti X
circuit.x(0)

# Lisää portti H
circuit.h(0)

# Piirretään lopuksi piiri
display(circuit.draw(output="mpl", scale=2))
result = execute(circuit, Aer.get_backend("statevector_simulator")).result()
out_state = result.get_statevector()
plot_bloch_multivector(out_state)

# %% [markdown]
# ## Tehtävä 3
# Hadamard eli $H$-portti muuttaa kubitin tilat $\ket 0$ ja $\ket 1$ superpositioon seuraavasti:
#
# $$
# H\ket 0 = \frac{1}{\sqrt 2} (\ket 0 +  \ket 1) = \ket +   \\
# H\ket 1 = \frac{1}{\sqrt 2} (\ket 0 -  \ket 1) = \ket -
# $$
#
# Huomaa, että näitä kyseisiä tiloja merkitään  $\ket +$ ja $\ket -$.
#
# $H$-portin matriisiesitys on seuraava:
#
# $$
# H=\frac{1}{\sqrt{2}}\left(\begin{matrix}
# 1&1\\
# 1&-1
# \end{matrix}\right)\
# $$
#
#
# a) Laske matriisiesitystä käyttäen, että
#
# $$
# \begin{align}
# H\ket 0 &= \ket + \text{  eli laske  }
# \frac{1}{\sqrt{2}}\left(\begin{matrix}
# 1&1\\
# 1&-1
# \end{matrix}\right)\ \left(\begin{matrix}
# 1\\
# 0
# \end{matrix}\right)
# \end{align}
# $$
#
#
# b) Laske matriisiesitystä käyttäen, että
#
# $$
# \begin{align}
# H\ket 1 &= \ket - \text{  eli laske  }
# \frac{1}{\sqrt{2}}\left(\begin{matrix}
# 1&1\\
# 1&-1
# \end{matrix}\right)\ \left(\begin{matrix}
# 0\\
# 1
# \end{matrix}\right)
# \end{align}
# $$
#
# Tehtävänä on siis muodostaa uudet kantavektorit $\ket +$ ja $\ket -$ kertomalla H-matriisilla alkuperäiset laskennallisen kannan kantavektorit $\ket 0$ ja $\ket 1$.

# %%
# a-kohta pythonilla tähän, arvot voi ilmoittaa float- arvoina eli liukulukuina
from math import sqrt

H =  1/sqrt(2)*np.matrix([[1, 1],[1, -1]])

print("H-portti\n", H)

# määritellään pystyvektorina kubitin kvanttitila 0:
q0 = np.matrix([[1],[0]])
print("alkutila 0 pystyvektorina\n", q0)

# määritellään pystyvektorina kubitin kvanttitila 1:
q1 = np.matrix([[0],[1]])
print("alkutila 1 pystyvektorina:\n", q1)

print("ket0 + ket1\n", q0+q1)

print("H* ket 0\n", H*q0, "\n tuloksena superpositiotila")
print("H* ket 1\n", H*q1)

print("H*H tulo on identiteettimatriisi I:\n", np.round(H*H))
print("Eli matriisin H käänteismatriisi on H itse, koska H*H=I")
# Out:
# H-portti
#  [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]
# alkutila 0 pystyvektorina
#  [[1]
#  [0]]
# alkutila 1 pystyvektorina:
#  [[0]
#  [1]]
# ket0 + ket1
#  [[1]
#  [1]]
# H* ket 0
#  [[0.70710678]
#  [0.70710678]]
#  tuloksena superpositiotila
# H* ket 1
#  [[ 0.70710678]
#  [-0.70710678]]
# H*H tulo on identiteettimatriisi I:
#  [[1. 0.]
#  [0. 1.]]
# Eli matriisin H käänteismatriisi on H itse, koska H*H=I

# %% [markdown]
# ## Tehtävä 4 kompleksiluvut lukiomatematiikassa
# Katso alla oleva video, jos kompleksiluvut ovat sinulle vieraita.
#
# [Paljon lisätietoa kompleksiluvuista](https://drive.google.com/file/d/1QAxPmMFSmLxi7kpMmRp1n3x_0gqKhpSG/view?usp=sharing)
#
# ### Tiivistelmä kompleksiluvuista
# Kompleksiluku on muotoa $z=a+bi$, missä $i$ on _imaginaariyksikkö_ eli luku, jolla on ominaisuus $i^2=-1$.
#
# Luku $a$ on kompleksiluvun reaaliosa ja luku $b$ imaginaariosa.
#
# Erilaisia kompleksilukuja ovat esimerkiksi $3+2i$, $-5i$ ja $13$.
#
# Kompleksiluvun $z=a+bi$ _liittoluku_ eli _kompleksikonjugaatti_ on $\overline{z}=a-bi$.
#
# Kompleksilukuja esitetään ns. kompleksitasossa, jossa kompleksilukua z havainnollistetaan tason pisteenä $(a,b)$. Kompleksiluvun itseisarvo eli _moduli_ ilmaisee tällöin kompleksiluvun paikkavektorin pituuden
#
# $$
# \left|z\right|=\left|a+bi\right|=\sqrt{a^2+b^2}
# $$
#
# > Huom: Pythonissa imaginaariyksikkö $i$ ilmaistaan $j$-kirjaimella.

# %%
# https://youtu.be/nEkzazc_7x8
from IPython.lib.display import YouTubeVideo
YouTubeVideo('nEkzazc_7x8', width=600, height=338)

# %%
# Esimerkki
# Huom: Pythonissa imaginaariyksikkö i kirjoitetaan j-kirjaimella.
a = 2+3j
print("kompleksiluku:",a)
print("imaginaariosa:",a.imag)
print("reaaliosa:",a.real)
print("luvun a moduli",np.abs(a))
print("liittoluku:",np.conjugate(a))
# Out:
# kompleksiluku: (2+3j)
# imaginaariosa: 3.0
# reaaliosa: 2.0
# luvun a moduli 3.605551275463989
# liittoluku: (2-3j)

# %% [markdown]
# Laske pythonilla (esimerkin avulla) kompleksiluvun $b= 1-2i$
#
# a) reaaliosa ja imaginaariosa
#
# b) liittoluku eli kompleksikonjugaatti
#
# c) moduli

# %%
# Ohjelmoi tehtävä 4 tähän
b = 6-2j
print("imaginaariosa:",b.imag)
print("reaaliosa:",b.real)
print("luvun a moduli",round(np.abs(b),2))
print("liittoluku:",np.conjugate(b))
# Out:
# imaginaariosa: -2.0
# reaaliosa: 6.0
# luvun a moduli 6.32
# liittoluku: (6+2j)

# %% [markdown]
# ## Tehtävä 5 matriisin transponointi ja kompleksikonjugaatti
#
# Kaksiulotteinen matriisi $A$:
#
# $$
# A=\left(\begin{matrix}
# a&b\\
# c&d
# \end{matrix}\right)\
# $$
#
# Matriisin $A$ transpoosi $A^T$ määritellään seuraavasti:
# $$
# A^T=\left(\begin{matrix}
# a&c\\
# b&d
# \end{matrix}\right)\
# $$
#
# Matriisin $A$ kompleksikonjugaatti $\overline A$ muodostetaan laskemalla jokaisen alkion liittoluku eli konjugaatti. Esimerkiksi:
#
# $$
# A=\left(\begin{matrix}
# i&3\\
# 2&1-2i
# \end{matrix}\right)
# \\
# \overline A=\left(\begin{matrix}
# -i&3\\
# 2&1+2i
# \end{matrix}\right)\
# $$
#
# Matriisin $A$ konjugaattitranspoosi eli $\overline{A^T}$ merkitään kvanttimekaniikassa $A^\dagger$:
#
# $$
# A^\dagger=\left(\begin{matrix}
# -i&2\\
# 3&1+2i
# \end{matrix}\right)\
# $$
#
# Pythonissa matriisin konjukaattitraspoosin saa kirjoittamalla `.H` (tulee sanasta hermiittinen konjugaatti). Esimerkiksi:
#
# ```python
# zero = np.matrix([[1], [0]])
# zero.H
# ```

# %%
A=np.matrix([[1, 0-1j], [2+1j, 4]])
print("matriisi A:\n", A)
print("Matriisin A transpoosi:\n", A.T)
print("Matriisin A konjugaattitranspoosi\n", A.H)
# Out:
# matriisi A:
#  [[1.+0.j 0.-1.j]
#  [2.+1.j 4.+0.j]]
# Matriisin A transpoosi:
#  [[1.+0.j 2.+1.j]
#  [0.-1.j 4.+0.j]]
# Matriisin A konjugaattitranspoosi
#  [[1.-0.j 2.-1.j]
#  [0.+1.j 4.-0.j]]

# %%
B=np.matrix([[1-2j,3-1j],[4-3j,4]])
# Muodosta matriisin B 
# a) transpoosi
# b) konjugaattitranspoosi
print("Matriisi B:\n",B)

print("Matriisin B transpoosi saadaan operaatiolla B.T\n", B.T)
print("Matriisin B konjugaattitranspoosi saadaan operaatiolla B.H\n", B.H)
# Out:
# Matriisi B:
#  [[1.-2.j 3.-1.j]
#  [4.-3.j 4.+0.j]]
# Matriisin B transpoosi saadaan operaatiolla B.T
#  [[1.-2.j 4.-3.j]
#  [3.-1.j 4.+0.j]]
# Matriisin B konjugaattitranspoosi saadaan operaatiolla B.H
#  [[1.+2.j 4.+3.j]
#  [3.+1.j 4.-0.j]]

# %% [markdown]
# ### Tehtävä 6
#
#  Kvanttilaskennassa on tapana käyttä _Diracin notaatiota_ esittämään kvanttitiloja.
#
# Määrittelemme kubitin laskennalliset kantatilat 0 ja 1 seuraavasti käyttämällä _ket_ vektori ja pystyvektoriesitystä:
#
# $$
# \begin{align}
# \ket 0 &= \begin{pmatrix} 1 \\ 0 \end{pmatrix} \\
# \ket 1 &= \begin{pmatrix} 0 \\ 1 \end{pmatrix}.
# \end{align}
# $$
#
# a) ket-vektorista saadaan muodostettua ns. bra-vektori laskemalla matriisiesityksessä kompleksikonjugaatin transpoosi $\bra 0 = \ket 0^\dagger $.
#
# Muodosta seuraavat _bra_-vektorit:
# $$
# \begin{align}
# \bra 0 &= \begin{pmatrix} 1 & 0 \end{pmatrix} \\
# \bra 1 &= \begin{pmatrix} 0 & 1 \end{pmatrix}.
# \end{align}
# $$
#
# ja laske laskekannallisen kannan kantavektorien sisätulot:
# $$
# \begin{align}
# \braket {0 | 0} = \begin{pmatrix} 1 & 0 \end{pmatrix} \begin{pmatrix} 1 \\ 0 \end{pmatrix}  =1
# \end{align}
# $$
#
# ja
#
# $$
# \begin{align}
# \braket {1 | 1}= \begin{pmatrix} 0 & 1 \end{pmatrix} \begin{pmatrix} 0 \\ 1 \end{pmatrix}=1.
# \end{align}
# $$
#
# ja erityisesti:
#
# $$
# \begin{align}
# \braket {1 | 0}= \begin{pmatrix} 0 & 1 \end{pmatrix} \begin{pmatrix} 1 \\ 0 \end{pmatrix}=0.
# \end{align}
# $$

# %%
# TEhtävä 6

zero = np.matrix([[1], [0]])
one = np.matrix([[0], [1]])

print("tilavektori 0:\n",zero)
print("tilavektori 1:\n",one)

print("tilan 0 bra vektori\n", zero.H)
print("tilan 1 bra vektori\n", one.H)

print("<0| * |0> =", (zero.H*zero)[0,0])

print("<1| * |1> =", (one.H*one)[0,0])

print("< 0| * |1> =", (zero.H*one)[0,0])
# Out:
# tilavektori 0:
#  [[1]
#  [0]]
# tilavektori 1:
#  [[0]
#  [1]]
# tilan 0 bra vektori
#  [[1 0]]
# tilan 1 bra vektori
#  [[0 1]]
# <0| * |0> = 1
# <1| * |1> = 1
# < 0| * |1> = 0

# %% [markdown]
# ### Tehtävä 7
#
# Seuraavalla kaavalla voidaan laskea todennäköisyys, että kubitti $\ket \psi$ havaitaan tilassa $\ket x$.
# $$
# P(\ket x)= |\braket {x | \psi}|^2 .
# $$
#
# a) Olkoon kubitti alkutilassa $\ket +$. Määritä todennäköisyys, että kubitin tilan mittauksessa saadaan mittaustulokseksi eli kubitin tilaksi $\ket 0$.
#
#
#
# b) Määritä todennäköisyys, että kubitti tilassa $\ket 0$ havaitaan tilassa $\ket +$.
#
# c) tulkitse vastaukset python kommenttiin

# %%
zero = np.matrix([[1], [0]])
one = np.matrix([[0], [1]])

plus = 1 / np.sqrt(2) * (zero + one)

print("P(0)=P(|0>) = |<0|+>|ˆ2 =",(np.abs(zero.H*plus)**2)[0,0] )

print("P(+)=P(|+>) = | <+|0>|^2=",round((np.abs(plus.H*one)**2)[0,0],1) )

#minus = 1 / np.sqrt(2) * (zero - one)


# c-kohdan vastauksesi:
# a) Kun superpositiotila + mitataan, niin z-akselin suuntaisessa laskennallisessa
# kannassa tilavektorin |+> Blochin pallon päiväntasaajalla oleva
# kärki on yhtä etäällä 0 ja 1 tilasta, eli mittaustuloksen 0 tn on 50%.

#b) Tilavektorin kärki tilassa 0 on yhtä kaukana
# x-akselin ja Blochin pallon leikkauspisteistä |+> ja |->
# Out:
# P(0)=P(|0>) = |<0|+>|ˆ2 = 0.4999999999999999
# P(+)=P(|+>) = | <+|0>|^2= 0.5
